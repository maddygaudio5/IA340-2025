# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd

df = pd.read_csv('s3://ia340-2025-35102/Crime.csv') # Load the daa from s3
df.head() #show the top 5 rows
# Out:
#    Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0    201194204         2305  180031343  06/25/2018 07:03:12 PM
# 1    201192754         3562  180029527  06/15/2018 09:28:52 AM
# 2    201197266         5404  180035053  07/15/2018 10:14:12 PM
# 3    201197538         2399  180035451  07/17/2018 10:11:04 PM
# 4    201194239         1399  180031372  06/25/2018 10:14:39 PM
#
#           Start_Date_Time           End_Date_Time NIBRS Code  Victims  \
# 0  06/22/2018 06:00:00 PM  06/22/2018 08:00:00 PM        23F        1
# 1  06/15/2018 09:28:00 AM  06/15/2018 09:28:00 AM        35A        1
# 2  07/15/2018 10:14:00 PM  07/15/2018 11:45:00 PM        90D        1
# 3  07/17/2018 01:40:00 PM  07/17/2018 02:20:00 PM        23H        1
# 4  06/25/2018 10:14:00 PM                     NaN        13B        1
#
#               Crime Name1                  Crime Name2  ...  PRA  \
# 0  Crime Against Property     Theft From Motor Vehicle  ...  546
# ...

# %%
df.shape #shows number of rows and columns #457140 rows, 30 columns
# Out:
# (457140, 30)

# %%
df ['Offence Code'] #select column of Offence Code
# Out:
# 0         2305
# 1         3562
# 2         5404
# 3         2399
# 4         1399
#           ...
# 457135    1399
# 457136    3699
# 457137    9113
# 457138    5404
# 457139    1399
# Name: Offence Code, Length: 457140, dtype: object

# %%
df.sort_values(by='CR Number') #sort by variable of CR Number
# Out:
#         Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 56550     201123928         9108   10011074                     NaN
# 235139    201097962         2305   10046679                     NaN
# 243306    201105753         1199   11000193                     NaN
# 63625     201136795         2303   11046201                     NaN
# 425405    201381596         9199   12027588                     NaN
# ...             ...          ...        ...                     ...
# 457121    201541705         2303  250037873  08/24/2025 06:02:00 PM
# 457097    201541711         1313  250037874  08/24/2025 05:56:49 PM
# 457083    201541712         2309  250037887  08/24/2025 08:30:55 PM
# 457065    201541719         4104  250037890  08/24/2025 08:56:45 PM
# 353290    201518834         9062  250057506                     NaN
#
#                Start_Date_Time           End_Date_Time NIBRS Code  Victims  \
# ...

# %%
df[0:5] #slice by rows
# Out:
#    Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0    201194204         2305  180031343  06/25/2018 07:03:12 PM
# 1    201192754         3562  180029527  06/15/2018 09:28:52 AM
# 2    201197266         5404  180035053  07/15/2018 10:14:12 PM
# 3    201197538         2399  180035451  07/17/2018 10:11:04 PM
# 4    201194239         1399  180031372  06/25/2018 10:14:39 PM
#
#           Start_Date_Time           End_Date_Time NIBRS Code  Victims  \
# 0  06/22/2018 06:00:00 PM  06/22/2018 08:00:00 PM        23F        1
# 1  06/15/2018 09:28:00 AM  06/15/2018 09:28:00 AM        35A        1
# 2  07/15/2018 10:14:00 PM  07/15/2018 11:45:00 PM        90D        1
# 3  07/17/2018 01:40:00 PM  07/17/2018 02:20:00 PM        23H        1
# 4  06/25/2018 10:14:00 PM                     NaN        13B        1
#
#               Crime Name1                  Crime Name2  ...  PRA  \
# 0  Crime Against Property     Theft From Motor Vehicle  ...  546
# ...

# %%
df.info() #shows data types and number of null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457140 entries, 0 to 457139
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Incident ID             457140 non-null  int64
#  1   Offence Code            457140 non-null  object
#  2   CR Number               457140 non-null  int64
#  3   Dispatch Date / Time    391090 non-null  object
#  4   Start_Date_Time         457140 non-null  object
#  5   End_Date_Time           206640 non-null  object
#  6   NIBRS Code              457140 non-null  object
#  7   Victims                 457140 non-null  int64
#  8   Crime Name1             457140 non-null  object
#  9   Crime Name2             457140 non-null  object
#  10  Crime Name3             457140 non-null  object
#  11  Police District Name    455787 non-null  object
#  12  Block Address           420535 non-null  object
#  13  City                    457101 non-null  object
# ...

# %%
df.describe() #statistical summary of data
# Out:
#         Incident ID     CR Number        Victims       Zip Code  \
# count  4.571400e+05  4.571400e+05  457140.000000  453770.000000
# mean   2.013111e+08  1.910913e+08       1.021766   20876.799160
# std    1.302001e+05  5.991453e+07       0.185011     139.911311
# min    2.010871e+08  1.001107e+07       1.000000       6.000000
# 25%    2.011990e+08  1.800369e+08       1.000000   20853.000000
# 50%    2.013086e+08  2.000436e+08       1.000000   20878.000000
# 75%    2.014206e+08  2.300157e+08       1.000000   20904.000000
# max    2.015417e+08  2.500575e+08      22.000000   29882.000000
#
#        Address Number       Latitude      Longitude
# count    4.206750e+05  457140.000000  457140.000000
# mean     8.366502e+03      37.628175     -74.246901
# std      1.601724e+04       7.395859      14.592960
# min      0.000000e+00       0.000000     -77.516700
# 25%      1.600000e+03      39.017520     -77.197100
# 50%      8.100000e+03      39.071080     -77.098700
# ...

# %%
#rename columns
df = df.rename(columns={"CR Number": "CR Num"})
df.head()
#renamed the column CR Number to CR Num
# Out:
#    Incident ID Offence Code     CR Num    Dispatch Date / Time  \
# 0    201194204         2305  180031343  06/25/2018 07:03:12 PM
# 1    201192754         3562  180029527  06/15/2018 09:28:52 AM
# 2    201197266         5404  180035053  07/15/2018 10:14:12 PM
# 3    201197538         2399  180035451  07/17/2018 10:11:04 PM
# 4    201194239         1399  180031372  06/25/2018 10:14:39 PM
#
#           Start_Date_Time           End_Date_Time NIBRS Code  Victims  \
# 0  06/22/2018 06:00:00 PM  06/22/2018 08:00:00 PM        23F        1
# 1  06/15/2018 09:28:00 AM  06/15/2018 09:28:00 AM        35A        1
# 2  07/15/2018 10:14:00 PM  07/15/2018 11:45:00 PM        90D        1
# 3  07/17/2018 01:40:00 PM  07/17/2018 02:20:00 PM        23H        1
# 4  06/25/2018 10:14:00 PM                     NaN        13B        1
#
#               Crime Name1                  Crime Name2  ...  PRA  \
# 0  Crime Against Property     Theft From Motor Vehicle  ...  546
# ...

# %%
df.isnull().sum() #number of rows containing null value
#1287269 rows containing null values
# Out:
# Incident ID                    0
# Offence Code                   0
# CR Num                         0
# Dispatch Date / Time       66050
# Start_Date_Time                0
# End_Date_Time             250500
# NIBRS Code                     0
# Victims                        0
# Crime Name1                    0
# Crime Name2                    0
# Crime Name3                    0
# Police District Name        1353
# Block Address              36605
# City                          39
# State                       9503
# Zip Code                    3370
# Agency                         0
# Place                          0
# Sector                         0
# Beat                           0
# PRA                            9
# Address Number             36465
# Street Prefix             436528
# Street Name                 1276
# Street Suffix             450888
# Street Type                 1662
# Latitude                       0
# Longitude                      0
# ...

# %%
df = df.dropna() #drop null values
df.isnull().sum()
# Out:
# Incident ID               0
# Offence Code              0
# CR Num                    0
# Dispatch Date / Time      0
# Start_Date_Time           0
# End_Date_Time             0
# NIBRS Code                0
# Victims                   0
# Crime Name1               0
# Crime Name2               0
# Crime Name3               0
# Police District Name      0
# Block Address             0
# City                      0
# State                     0
# Zip Code                  0
# Agency                    0
# Place                     0
# Sector                    0
# Beat                      0
# PRA                       0
# Address Number            0
# Street Prefix             0
# Street Name               0
# Street Suffix             0
# Street Type               0
# Latitude                  0
# Longitude                 0
# Police District Number    0
# Location                  0
# dtype: int64

# %%
df['Crime Name1'].value_counts() #show the count of unique values
# Out:
# Series([], Name: count, dtype: int64)
